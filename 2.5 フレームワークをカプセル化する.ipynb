# %%
from thinkbayes import Suite


class Monty(Suite):

    def Likelihood(self, data, hypo):
        if hypo == data:
            return 0
        elif hypo == 'A':
            return 0.5
        else:
            return 1

# %%
suite = Monty('ABC')
suite.Update('B')

suite.Items()
# Out:
# dict_items([('A', 0.3333333333333333), ('B', 0.0), ('C', 0.6666666666666666)])
